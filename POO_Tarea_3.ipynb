# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import plot

# %%
#1. Genera una lista que consista de  20  números que estén en el intervalo  [−1,1] . Llámala Lista_1.

lista_1=[random.uniform(-1, 1,)for _ in range(20)]
lista_1
# Out:
# [-0.26092533133200324,
#  -0.7446968290194502,
#  -0.27923438801983336,
#  -0.460994194004668,
#  -0.048549392583509876,
#  -0.44875711066271085,
#  -0.016531008296542637,
#  -0.14107840248582315,
#  -0.3715043714027846,
#  0.26851955190538224,
#  -0.18082895678767863,
#  0.9085758755996038,
#  -0.5819817940629084,
#  -0.934618231381843,
#  -0.562304536012671,
#  0.9086062454309252,
#  -0.3905427922377902,
#  -0.9658329222929414,
#  0.5458398631734169,
#  0.6041243679534183]

# %%
#2. Genera una lista que consista de  20  números que sean enteros en el intervalo  [1500,3000] . Llámala Lista_2.
lista_2=[random.randint(1500,3000)for _ in range(20)]
lista_2
# Out:
# [2407,
#  1584,
#  2354,
#  1936,
#  1733,
#  2743,
#  2850,
#  1929,
#  1783,
#  2923,
#  2607,
#  1763,
#  1527,
#  2117,
#  2402,
#  2782,
#  2236,
#  1991,
#  2912,
#  2295]

# %%
#3. Crea un diccionario cuyas llaves sean "CapSmall" y "CapLarge" y sus valores sean la Lista_1 y Lista_2, respectivamente.
Caps= {"CapSmall":lista_1,"CapLarge":lista_2}
Caps
# Out:
# {'CapSmall': [-0.26092533133200324,
#   -0.7446968290194502,
#   -0.27923438801983336,
#   -0.460994194004668,
#   -0.048549392583509876,
#   -0.44875711066271085,
#   -0.016531008296542637,
#   -0.14107840248582315,
#   -0.3715043714027846,
#   0.26851955190538224,
#   -0.18082895678767863,
#   0.9085758755996038,
#   -0.5819817940629084,
#   -0.934618231381843,
#   -0.562304536012671,
#   0.9086062454309252,
#   -0.3905427922377902,
#   -0.9658329222929414,
#   0.5458398631734169,
#   0.6041243679534183],
#  'CapLarge': [2407,
#   1584,
#   2354,
#   1936,
#   1733,
#   2743,
#   2850,
#   1929,
#   1783,
#   2923,
#   2607,
#   1763,
#   1527,
#   2117,
#   2402,
#   2782,
#   2236,
#   1991,
#   2912,
#   2295]}

# %%
type(Caps)
# Out:
# dict

# %%
#4. Crea un DataFrame a partir del diccionario del punto anterior. Llámalo df.
df=pd.DataFrame(Caps)
df
# Out:
#     CapSmall  CapLarge
# 0  -0.260925      2407
# 1  -0.744697      1584
# 2  -0.279234      2354
# 3  -0.460994      1936
# 4  -0.048549      1733
# 5  -0.448757      2743
# 6  -0.016531      2850
# 7  -0.141078      1929
# 8  -0.371504      1783
# 9   0.268520      2923
# 10 -0.180829      2607
# 11  0.908576      1763
# 12 -0.581982      1527
# 13 -0.934618      2117
# 14 -0.562305      2402
# 15  0.908606      2782
# 16 -0.390543      2236
# 17 -0.965833      1991
# 18  0.545840      2912
# 19  0.604124      2295

# %%
#5. Reindexa los índices poniendo Año 1 ,...,  Año 20.
df=pd.DataFrame(Caps, index=[f"Año {i+1}" for i in range(20)])
df
# Out:
#         CapSmall  CapLarge
# Año 1  -0.260925      2407
# Año 2  -0.744697      1584
# Año 3  -0.279234      2354
# Año 4  -0.460994      1936
# Año 5  -0.048549      1733
# Año 6  -0.448757      2743
# Año 7  -0.016531      2850
# Año 8  -0.141078      1929
# Año 9  -0.371504      1783
# Año 10  0.268520      2923
# Año 11 -0.180829      2607
# Año 12  0.908576      1763
# Año 13 -0.581982      1527
# Año 14 -0.934618      2117
# Año 15 -0.562305      2402
# Año 16  0.908606      2782
# Año 17 -0.390543      2236
# Año 18 -0.965833      1991
# Año 19  0.545840      2912
# Año 20  0.604124      2295

# %%
#6. Realiza una explicación de la estadística descriptiva de tu DataFrame.
df.describe()
# Out:
#         CapSmall     CapLarge
# count  20.000000    20.000000
# mean   -0.157636  2243.700000
# std     0.553013   455.373196
# min    -0.965833  1527.000000
# 25%    -0.486322  1892.500000
# 50%    -0.270080  2265.500000
# 75%     0.054732  2641.000000
# max     0.908606  2923.000000

# %%
#7. ¿Cuál es el valor mínimo de la columna "CapSmall"?

valor_min_CapSmall = df["CapSmall"].min()
print("El valor mínimo en la columna /CapSmall/ es:", valor_min_CapSmall)
# Out:
# El valor mínimo en la columna /CapSmall/ es: -0.9658329222929414

# %%
#8. ¿Cuál es "CapLarge" promedio del año 10 al año 20?
df_CL=df.drop(columns=["CapSmall"])
df10_20=df_CL.iloc[9:20]
print(df10_20)

promedio_CapLarge = df10_20["CapLarge"].mean()
print("El promedio de la Columna /CapLarge/ del año 10 al 20 es:", promedio_CapLarge)
# Out:
#         CapLarge
# Año 10      2923
# Año 11      2607
# Año 12      1763
# Año 13      1527
# Año 14      2117
# Año 15      2402
# Año 16      2782
# Año 17      2236
# Año 18      1991
# Año 19      2912
# Año 20      2295
# El promedio de la Columna /CapLarge/ del año 10 al 20 es: 2323.181818181818

# %%
#9. Realiza una gráfica de Año contra "CapLarge".
df["CapLarge"].plot(label="df", figsize=(14,6))
# Out:
# <Axes: >

# %%
#10. Muestra el DataFrame que obtienes si tomas aquellos valores de "CapLarge" mayores a 2000 . ¿Cuál es la dimensión (shape) de tu nueva base de datos?
df_filtro= df_CL[df_CL["CapLarge"] > 2000]
df_filtro
# Out:
#         CapLarge
# Año 1       2407
# Año 3       2354
# Año 6       2743
# Año 7       2850
# Año 10      2923
# Año 11      2607
# Año 14      2117
# Año 15      2402
# Año 16      2782
# Año 17      2236
# Año 19      2912
# Año 20      2295

# %%
#Dimension base de datos
df_filtro.shape
# Out:
# (12, 1)
