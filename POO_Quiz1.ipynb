# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import plot

# %%
#1.- Crea un diccionario que contenga 3 llaves que sean de tipo string y cuyos valores sean una lista que contenga 5 valores (3 numéricos y 2 flotantes).
calif = {
    "Fer": [10, 9, 7, 8.5, 9.7],
    "Manu": [8, 9, 6, 7.5, 8.2],
    "Toño": [10, 10, 4, 7.8, 8.4]}

print(calif)
# Out:
# {'Fer': [10, 9, 7, 8.5, 9.7], 'Manu': [8, 9, 6, 7.5, 8.2], 'Toño': [10, 10, 4, 7.8, 8.4]}

# %%
#2.- A partir del diccionario anterior, muestra a sus ítems. ¿Qué tipo de objeto se obtiene?
calif.items()
# Out:
# dict_items([('Fer', [10, 9, 7, 8.5, 9.7]), ('Manu', [8, 9, 6, 7.5, 8.2]), ('Toño', [10, 10, 4, 7.8, 8.4])])

# %%
type(calif.items())
# Out:
# dict_items

# %%
#3.- Crea un panel de datos usando tu diccionario. Realiza tres segregaciones distintas.
import pandas as pd
califgraf=pd.DataFrame(calif,index=[f"Semestre{i+1}"for i in range (5)])

# %%
califgraf
# Out:
#             Fer  Manu  Toño
# Semestre1  10.0   8.0  10.0
# Semestre2   9.0   9.0  10.0
# Semestre3   7.0   6.0   4.0
# Semestre4   8.5   7.5   7.8
# Semestre5   9.7   8.2   8.4

# %%
#Segregacion 1
califgraf.iloc[1]
# Out:
# Fer      9.0
# Manu     9.0
# Toño    10.0
# Name: Semestre2, dtype: float64

# %%
#Segregacion 2
califgraf["Toño"]
# Out:
# Semestre1    10.0
# Semestre2    10.0
# Semestre3     4.0
# Semestre4     7.8
# Semestre5     8.4
# Name: Toño, dtype: float64

# %%
#Segregacion 3
e = califgraf.drop(columns= ["Toño", "Fer"])
e
# Out:
#            Manu
# Semestre1   8.0
# Semestre2   9.0
# Semestre3   6.0
# Semestre4   7.5
# Semestre5   8.2

# %%
#4.- Realiza un breve análisis descriptivo de tu panel de datos. Explica los valores que obtienes.
califgraf.describe()
# Out:
#              Fer      Manu       Toño
# count   5.000000  5.000000   5.000000
# mean    8.840000  7.740000   8.040000
# std     1.184483  1.112654   2.459268
# min     7.000000  6.000000   4.000000
# 25%     8.500000  7.500000   7.800000
# 50%     9.000000  8.000000   8.400000
# 75%     9.700000  8.200000  10.000000
# max    10.000000  9.000000  10.000000

# %% [markdown]
# Count es cuantas valores hay por persona, mean es la media donde evidentemente yo tengo la mas alta. Std es la desviacion estandar. Min es el valor minimo y max el maximo. y los porcentajes son percentiles, que separan los valores mas bajos depende el porcentaje.

# %%
#5.- Realiza dos filtros de búsqueda sobre tu panel de datos.
#Muestra las calificaciones de todos en los semestres donde Toño no reprobo
califgraf[califgraf["Toño"]>6]
# Out:
#             Fer  Manu  Toño
# Semestre1  10.0   8.0  10.0
# Semestre2   9.0   9.0  10.0
# Semestre4   8.5   7.5   7.8
# Semestre5   9.7   8.2   8.4

# %%
califgraf.iloc[2:4]
# Out:
#            Fer  Manu  Toño
# Semestre3  7.0   6.0   4.0
# Semestre4  8.5   7.5   7.8
